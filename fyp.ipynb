# %%
import pandas as pd
import numpy as np
import nltk
from sklearn.naive_bayes import MultinomialNB

# %%
df = pd.read_csv('D:/DATA/Sem8/fyp/AnnotatedData.csv')
# create series of true and false. True is assigned for yes/no. False for undefine
defined=df['Purchase Intention'] != "undefined" 
#output dataframe without undeined
df2=df[defined]
#replace no PI with no
df3=df2.replace("No PI","no")
#replace PI with yes
final_df=df3.replace("PI","yes")
final_df
# Out:
#     Purchase Intention     id  \
# 5                   no  108.0
# 6                  yes  109.0
# 7                  yes  110.0
# 9                  yes  112.0
# 11                  no  115.0
# 13                  no  117.0
# 14                  no  118.0
# 16                  no  120.0
# 20                 yes  126.0
# 22                 yes  128.0
# 23                  no  129.0
# 27                 yes  135.0
# 30                  no  138.0
# 31                  no  139.0
# 33                  no  141.0
# 36                 yes  144.0
# 40                 yes  148.0
# 41                  no  149.0
# 44                 yes  152.0
# 51                 yes  159.0
# 52                 yes  160.0
# 53                  no  161.0
# 59                 yes  167.0
# 60                 yes  168.0
# 61                 yes  169.0
# 66                 yes  176.0
# 67                  no  177.0
# 69                 yes  180.0
# 71                 yes  182.0
# 76                 yes  187.0
# ..                 ...    ...
# 110                yes  224.0
# 115                 no  229.0
# 116                 no  230.0
# 119                yes  233.0
# 120                yes  234.0
# 125                 no  239.0
# 126                yes  240.0
# 129                 no  243.0
# 130                yes  244.0
# 134                yes  248.0
# 135                 no  249.0
# 136                 no  250.0
# 138                yes  252.0
# 143                yes  257.0
# 144                 no  258.0
# 150                yes  264.0
# 151                yes  265.0
# 153                yes  267.0
# 154                yes  268.0
# 158                yes  272.0
# 159                yes  273.0
# 161                yes  275.0
# 162                 no  276.0
# 167                 no  281.0
# 171                 no  285.0
# 173                 no  287.0
# 174                yes  288.0
# 177                 no  291.0
# 180                yes  294.0
# 182                yes  296.0
#
#                                                   text
# 5      The camera on an  iPhone X  is fucking horrific
# 6    I'm so buzzing that I finally get an  iPhone X...
# 7                                Buy  iPhone x  for me
# 9    I liked a @YouTube  video  http:// youtu.be/cM...
# 11   Got my Pixel 3 finally. So here is the verdict...
# 13   Seriously considering trading in my  iPhone X ...
# 14   Apple no longer sells the  iPhone X , but that...
# 16   I liked a @YouTube  video  http:// youtu.be/sQ...
# 20   omg we live for  iphone x  quality hshshsh  pi...
# 22   The screen on the  iPhone X  is amazing! Thank...
# 23                  i have an  iphone X  u silly bitch
# 27   The biggest struggle with having an  iPhone X ...
# 30   @ AppleSupport  #iphonex  With calls on my pho...
# 31   BIG MONEY I want an  iphone x    but money is ...
# 33   Just got the  iPhone X  compliments of Verizon...
# 36   the back of the lens rotates - there is a smal...
# 40   Want to win SENA Cases iPhone Xs Giveaway Ente...
# 41   Everything about #iOS  is #shit ! Even it’s #h...
# 44                           time to get the  iphone x
# 51   I have to wait until Monday to get the  iPhone...
# 52                                       Vem  iPhone x
# 53       I want a new phone I’m sick of this  iPhone X
# 59   Im feeling very behind the times with my iPhon...
# 60                              My  iPhone X  came in
# 61             In need of an  iPhone X , for business.
# 66   Best Cyber Week Deals on iPhone XS, iPhone XR,...
# 67   Stupidity is when you buy an  iPhone X  max  t...
# 69   The  iPhone X  can use an iPhone 7 phone charg...
# 71   This lady is buying 7  iPhone X ’s Maxes.........
# 76   Yeah, so far Apple has done a good job with OL...
# ..                                                 ...
# 110  Looks like u now use an  iPhone x \nCan I have...
# 115           Wtf  iPhone X  takes very long to charge
# 116  Tecno Y3 or so had face unlock.\nSamsung S3 or...
# 119  Thanks. I’m interested in the  IPhone X . I wa...
# 120  # Win  an #iPhone  X with Envirofone this Fest...
# 125  Lololol everyone knows the  iPhoneX  was the o...
# 126  My mum got scammed $200 trying to buy an  iPho...
# 129  iOS as a whole doesn’t feel that polished for ...
# 130  I got a  iPhone X /10 for sale.\n\nIt’s a 6 an...
# 134  IPhone X  \nIPhone 6 regular y plus \nIphone 7...
# 135  I'm replying to this from a S9. Trust me when ...
# 136                            Nope bell mts  iPhone X
# 138  To the unclaimed Euro millions winner in Skegn...
# 143  Bro this  iPhone X  camera quality better come...
# 144  I would be onboard with this with one exceptio...
# 150  Bullshit! Apple Watch, AirPods, iPad Pro,  iPh...
# 151                    letter,thanks fucking  iPhone X
# 153  That’s why it’s and  iPhone X  or iPhone decad...
# 154                                for the  iPhone X !
# 158  Yeah, talking to my friend who’s an AT&T manag...
# 159  10 Friday get here so I can get the  iPhone X ...
# 161  Hello David! You can find the  iPhone X 's pri...
# 162  But instead of giving out just one for example...
# 167  I don find that 4K Naira  IPhone X  for the Ju...
# 171  You're right there. They're even more bonkers!...
# 173  My daughter's  iPhone X  can't even cast music...
# 174                      I really love the  iPhone X
# 177  Obviously P is better but they're too fucking ...
# 180  i’m still getting the “opportunity to win an  ...
# 182  It is real, important, and if you actually wan...
#
# [76 rows x 3 columns]

# %%
# create series of true and false. False is assigned for yes/no. True is for undefined
undefined=df['Purchase Intention'] == "undefined" 
#output dataframe without undeined
df3=df[undefined]
df3
# Out:
#     Purchase Intention     id  \
# 0            undefined  102.0
# 1            undefined  103.0
# 2            undefined  105.0
# 3            undefined  106.0
# 4            undefined  107.0
# 8            undefined  111.0
# 10           undefined  113.0
# 12           undefined  116.0
# 15           undefined  119.0
# 17           undefined  121.0
# 18           undefined  124.0
# 19           undefined  125.0
# 21           undefined  127.0
# 24           undefined  130.0
# 25           undefined  132.0
# 26           undefined  134.0
# 28           undefined  136.0
# 29           undefined  137.0
# 32           undefined  140.0
# 34           undefined  142.0
# 35           undefined  143.0
# 37           undefined  145.0
# 38           undefined  146.0
# 39           undefined  147.0
# 42           undefined  150.0
# 43           undefined  151.0
# 45           undefined  153.0
# 46           undefined  154.0
# 47           undefined  155.0
# 48           undefined  156.0
# ..                 ...    ...
# 140          undefined  254.0
# 141          undefined  255.0
# 142          undefined  256.0
# 145          undefined  259.0
# 146          undefined  260.0
# 147          undefined  261.0
# 148          undefined  262.0
# 149          undefined  263.0
# 152          undefined  266.0
# 155          undefined  269.0
# 156          undefined  270.0
# 157          undefined  271.0
# 160          undefined  274.0
# 163          undefined  277.0
# 164          undefined  278.0
# 165          undefined  279.0
# 166          undefined  280.0
# 168          undefined  282.0
# 169          undefined  283.0
# 170          undefined  284.0
# 172          undefined  286.0
# 175          undefined  289.0
# 176          undefined  290.0
# 178          undefined  292.0
# 179          undefined  293.0
# 181          undefined  295.0
# 183          undefined  297.0
# 184          undefined  298.0
# 185          undefined  299.0
# 186          undefined  300.0
#
#                                                   text
# 0    Oppo has a clever idea for eliminating the not...
# 1    Just saw this on eBay : Apple  iPhone X  a1901...
# 2    @ AppleSupport  my  iPhone X  keeps staying on...
# 3    The best  iPhone X  cases – CNET  https://www....
# 4    Apple  iPhone X , Fully Unlocked 5.8", 256 GB ...
# 8    The best  iPhone X  cases## CNET   https:// go...
# 10   I have no data to back this up but I think the...
# 12   # window  #squirrel  #cardinal  #birds  #mushr...
# 15   Here's your chance to Win  iPhone X  offered a...
# 17   iPhone X  camera made me forget I look bummy  ...
# 18   Just got the  iPhone X  Max and it’s way too b...
# 19             Walking around with a naked  iPhone X
# 21               IPhone X   pic.twitter.com/Tadt39ZkGT
# 24   Check out what I found. Ultra Slim Frosted Cas...
# 25   I feel like everyone has an  iPhone X  or Xs n...
# 26      Tesla,  iPhone X , Apple Watch and suede shoes
# 28   Greetings everyone! Time for #YOUROC60min ! No...
# 29      I can’t even do it cause I have an  iPhone X
# 32   IPhone X  Forsale BrandNew With AnyBody   pic....
# 34   Reunited an  iPhoneX  with its owner today (fo...
# 35   Huawei P20 Lite, a pathetic try to be  iPhone ...
# 37   Check out what I just added to my closet on Po...
# 38   Rt and dm me If you want your 10 dollars btc t...
# 39   Check out USB Cord Cable Braided Light Fast Ch...
# 42   Hands-On With Caviar's $4,400 'Tesla' Solar-Ch...
# 43   It’s just a standard  iPhone X . I gotta open ...
# 45   I can’t wait until my  iPhone X  is done upgra...
# 46         Guys , how do I switch off the  iPhone X  ?
# 47   people who post  iphone x  screenshots ELECTIC...
# 48   Early morning views #sunrise  #sky  #skyline  ...
# ..                                                 ...
# 140  I shot this picture today with my  iPhone X  a...
# 141  Refurb OtterBox Pursuit Case for  iPhone X  fo...
# 142  @ snapchatsupport  When will you be updating t...
# 145                            the  iPhone X .2 Jaguar
# 146  Seattle out of my bedroom window at 12:41, Nov...
# 147  5d | 3d | Temper glass | Premium | edge to edg...
# 148  Free  iPhone X  - Get Free iPhone - Apple iPho...
# 149  iPhone x  software problem. Phone died two day...
# 152  Three Points - Job Done   \n\n#acmilan   #ميلا...
# 155          Selling my white  iPhone X  64GB $700 obo
# 156  Anyone else with the  iPhone X  having overhea...
# 157  Theme by @tvdMD  \nWalls by @AR72014  \nWidget...
# 160  Latest from Scandy! Volumetric Video on  Iphon...
# 163  Like a plague\n.\n.\n.\n#fly  #leaf  #decay  #...
# 164  Manchester Central at night. Beetham Tower Hil...
# 165  iPhone X , S7/S6 edge -N3000\nXs max N3000\n Y...
# 166  Either this is fake, or she is using an  iPhon...
# 168  Mine too, mainly because I bought an  iPhone X...
# 169  Lord bless the  IPhone X  camera zoom for allo...
# 170  Guys why are we desperate ? Oh u wanna buy Ben...
# 172                                           iPhone X
# 175  iPhone X  6S 7 8 Plus Case Non-Slip Hybrid Dua...
# 176  I’m a bad man on that  iPhone X  camera... of ...
# 178  Iphone X  survives Boiling water test.  https:...
# 179  My  iPhone X  is already performing at 99% bat...
# 181  Apple resumes  iPhone X  production in face of...
# 183  What would you call a guy that uses a girl for...
# 184  It's  iPhone x  that will snap the picture is ...
# 185  Hey friends, I'm selling this " iphone x  veri...
# 186  iPhone X  Clean Mode was successfully unlocked...
#
# [111 rows x 3 columns]

# %%
def text_concat():
    text=""
    for x in final_df["text"]:
        text=text +str(x)
    return text
corpus=text_concat()

# %%
import re
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

def removeStopWords(text):
    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(text) 
    filtered_sentence = [] 
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w.lower()) 
    #return list of corpus without stop words in a list.        
    return filtered_sentence  

def removePunc(eachText):
    remove_punc = re.sub(r'[^\w\s]','',eachText)
    #return corpus with out punctuation.
    return remove_punc



def clean_data(corpus):
    remove_punc=removePunc(corpus)
    li_remove_stopWords= removeStopWords(remove_punc)
    return li_remove_stopWords

li_cleaned_text=clean_data(corpus)
# bprint(li_cleaned_text)
# Out:
# ['the', 'camera', 'iphone', 'x', 'fucking', 'horrificim', 'buzzing', 'i', 'finally', 'get', 'iphone', 'x', 'tomorrow', 'buy', 'iphone', 'x', 'mei', 'liked', 'youtube', 'video', 'http', 'youtubecmiz1lcq5fka', 'iphone', 'x', 'cinematic', 'toronto', 'canada', '4kgot', 'pixel', '3', 'finally', 'so', 'verdict', '1', 'its', 'much', 'smarter', 'iphone', 'x', 'i', 'think', 'one', 'important', 'yet', 'overlooked', '2', 'the', 'camera', 'ridiculous', '3', 'its', 'smooth', 'iphone', 'apple', 'ecosystem', 'awesome', '4', 'its', 'enjoyable', 'useseriously', 'considering', 'trading', 'iphone', 'x', 'flip', 'phone', 'face', 'recognition', 'crap', 'creeping', 'bigbrother', 'iphonexrapple', 'longer', 'sells', 'iphone', 'x', 'doesnt', 'mean', 'shouldnt', 'protect', 'one', 'https', 'cnetco2ds00h2', 'i', 'liked', 'youtube', 'video', 'http', 'youtubesqldxppmsea', 'smashing', 'the', 'iphone', 'x', 'in', 'public', 'prank', '4omg', 'live', 'iphone', 'x', 'quality', 'hshshsh', 'pictwittercom4lipdpjbufthe', 'screen', 'iphone', 'x', 'amazing', 'thank', 'goodness', 'i', 'went', 'og', 'iphone', 'x', 'instead', 'iphone', 'xr', 'like', 'i', 'originally', 'planned', 'that', 'blue', 'color', 'tempting', 'though', 'loli', 'iphone', 'x', 'u', 'silly', 'bitchthe', 'biggest', 'struggle', 'iphone', 'x', 'easy', 'screenshot', 'things', 'ive', 'month', 'ive', 'screenshotted', 'many', 'peoples', 'snapchat', 'instagram', 'stories', 'accident', 'applesupport', 'iphonex', 'with', 'calls', 'phone', 'i', 'cant', 'hear', 'end', 'unless', 'speaker', 'every', 'time', 'i', 'take', 'issue', 'apple', 'n', 'throw', 'new', 'iphonex', 'right', 'i', '3rd', 'replacement', 'phone', 'what', 'warranty', 'ends', 'shambig', 'money', 'i', 'want', 'iphone', 'x', 'money', 'money', 'hmmmmjust', 'got', 'iphone', 'x', 'compliments', 'verizons', 'bf', 'sending', 'texts', 'personal', 'emoji', 'anyone', 'i', 'know', 'this', 'wont', 'end', 'wellthe', 'back', 'lens', 'rotates', 'small', 'set', 'screw', 'rotate', 'v', 'vertical', 'iphone', 'x', '133x', 'want', 'win', 'sena', 'cases', 'iphone', 'xs', 'giveaway', 'enter', 'win', '1st', 'prize', 'iphone', 'x', 'i', 'entered', 'win', 'http', 'gvwyioemu3ld0', 'everything', 'ios', 'shit', 'even', 'haptics', 'dinosaur', 'thugnology', 'applepay', 'iphone', 'x', 'sux', 'ux', 'time', 'get', 'iphone', 'xi', 'wait', 'monday', 'get', 'iphone', 'x', 'vem', 'iphone', 'xi', 'want', 'new', 'phone', 'im', 'sick', 'iphone', 'xim', 'feeling', 'behind', 'times', 'iphone', '7', 'right', 'i', 'didnt', 'know', 'iphone', 'x', 'existedmy', 'iphone', 'x', 'came', 'in', 'need', 'iphone', 'x', 'businessbest', 'cyber', 'week', 'deals', 'iphone', 'xs', 'iphone', 'xr', 'iphone', 'x', 'iphone', '8', 'http', 'dlvritqsrghp', 'pictwittercom0w6rdfvpfmstupidity', 'buy', 'iphone', 'x', 'max', 'faulty', 'reasonable', 'person', 'help', 'fix', 'nigeriathe', 'iphone', 'x', 'use', 'iphone', '7', 'phone', 'charger', 'thats', 'win', 'i', 'guessthis', 'lady', 'buying', '7', 'iphone', 'x', 'maxes', 'outright', 'breadyeah', 'far', 'apple', 'done', 'good', 'job', 'oled', 'i', 'havent', 'read', 'stuff', 'iphone', 'x', 'earlier', 'apple', 'watch', 'ui', 'elements', 'stuck', 'i', 'hope', 'see', 'promotion', 'elsewhere', 'might', 'get', 'tough', 'mac', 'using', 'igpus', 'thoughtoday', 'received', 'brand', 'new', 'iphone', 'x', 'day', 'handing', 'old', 'smashed', 'one', 'understand', 'pay', '16', 'month', 'insurance', 'iphone', 'x', 'basically', 'lolmy', 'iphone', 'x', 'came', 'im', 'excited', 'i', 'cant', 'wait', 'activate', 'make', 'owni', 'got', 'iphone', 'x', 'gained', '100', 'followers', 'roadto500k', 'pictwittercomrefhi3gc8vnanthey', 'told', 'dream', 'big', 'yeah', 'iphone', 'xstand', 'chance', 'win', 'iphonex', 'simply', 'click', 'link', 'http', 'sasautoscomlink43316119', '3t5g9ysc1sc1l1ppy4291063', 'whats', 'difference', 'iphone', 'x', 'iphone', 'x', 'x', 'max', 'siracusa', 'listened', 'hypercritical', '16', 'whole', 'episode', 'lcd', 'ghosting', 'horrible', 'doesnt', 'oled', 'ghosting', 'annoy' ...

# %%
def make_unique_li(li_cleanText):
    unique_words_set= set(li_cleanText)
    unique_word_li = list(unique_words_set)
    return unique_word_li
uniqueWords=print(make_unique_li(li_cleaned_text))
# Out:
# ['buy', 'v', 'ee', 'pm', 'lcd', 'pricing', 'emoji', 'better', 'next', 'reduce', 'onto', 'planned', 'buyingi', 'new', 'scammed', 'black', 'apple', 'iphonex', 'winner', 'skegness', 'applesupport', 'giving', 'come', 'x', 'read', 'vouchercloud', 'verdict', 'keep', '150', '4', '3', 'bf', '400k', 'set', '3t', 'sync', 'see', 'handing', 'sure', 'lame', 'it', 'but', 'long', 'small', 'pictwittercom0w6rdfvpfmstupidity', 'david', 'love', 'protect', 'want', 'advantage', 'came', 'o2', '4omg', 'screen', 'y3', 'tough', '3rd', '1k', 'replying', 'take', 'sexy', 'use', 'og', 'guessthis', 'horrificim', 'reasonable', 'told', 'sim', 'monday', 'think', 'also', 'hypercritical', 'received', 'buggati', 'link', 'episode', 'cast', 'pictwittercomrefhi3gc8vnanthey', 'something', 'flagshipsbullshit', 'dream', 'ui', 'benefiti', 'example', 'igpus', 'regular', 'brand', 'gaming', 'bro', 'shop', 'contract', 'amazing', 'lost', 'steep', 'thoughtoday', 'twittercomafuaasamstatu', 'folk', 'color', 'unless', 'dinosaur', 'obviously', 'shambig', 's1068249266026614784', 'someones', 'saying', 'ecosystem', 'trading', 'hope', 'buzzing', 'pros', 'omo', 'iphonexmy', 'time', 'like', 'tabs', 'face', 'lolmy', 'sony', 'nigeriathe', 'fucking', 'pocket', 'basically', 'mum', 'this', 'iphonexrapple', 'interested', 'prank', '24', 's9', 'youtubesqldxppmsea', 'tempting', 'person', 'tv', 'elements', 'canada', '4k', 'methis', 'back', 'consideration', 'ssame', 'shouldnt', 'oled', 'pic', 'ridiculous', 'themiphone', 'important', 'hshshsh', 'accident', '75', 'screw', 'ghosting', 'click', 'instagram', 'im', 'vem', 'googlyafuzy', 'max4200', 'activate', '200', 'what', 'horrible', 'dont', 'knows', 'wont', 'could', 'month', 'written', 'help', 'enjoyable', 'pixel', 'inch', 'still', '3t5g9ysc1sc1l1ppy4291063', 'httpswww', 'significant', 'using', 'why', 'available', 'xthats', 'week', 'sick', 'ipad', 'vertical', 'thanks', 'real', 'deals', 'hear', 'need', 'whole', 'ferrari', '45', 'earlier', 'carry', 'xim', 'struggling', 'ends', 'buying', 'wouldnt', 'roundmy', 'match', '64gb', 'goodness', 'especially', 'listened', 'stuff', 'one', 'different', 'screenshotted', 'many', 'actually', 'considering', 'bonkers', 'getting', 'xto', 'thank', 'personal', 'deal', 'backgrounds', 'going', 'sells', 'customers', 'the', '8', 'seen', 'rotate', '13', 'ive', 'siracusa', 'calls', 'roadto500k', 'friend', 'silly', 'useseriously', 'much', 'u', 'envirofone', 'its', 'feel', 'behind', 'saw', '133x', 'applepay', 'excited', 'losers', 'liked', 'toronto', 'crazy', 'havent', 'cnetco2ds00h2', 'trying', 'dive', 'even', 'things', 'experienced', 'lady', 'n', 'daughters', 'dickhead', 'gained', 's3', '78', 'scroll', 'iphonexlololol', 'serious', 'mts', 'drives', 'terms', 'live', '4gb', 'owni', 'pay', 'doesnt', '128gb', 'kdbut', 'tire', 'bell', 'hit', 'really', 'texts', 'prize', 'wellthe', 'features', 'sena', 'charger', 'faulty', 'friday', 'annoy', 'decade', 'fullestiphone', 'went', 'look', 'sux', 'throw', 'screenshots', 'cameras', 'unclaimed', 'nokia', 'they', 'feeling', 'app', 'vouchercloudcomdid1988896r', 'usesnope', 'jumia', 'know', 'you', '7', 'plus', 'music', 'businessbest', 'big', 'followers', 'retweet', 'ohyoure', 'gvwyioemu3ld0', 'every', 'would', 'got', 'cases', 'loli', 'stuck', 'smashed', 'salesomeone', 'gear', 'good', 'yeah', 'mean', 'stories', 'enter', '4kgot', 'so', 'recognition', 'screenshot', 'promotion', 'bet', 'my', 'xr', 'maxhello', 'main', '6', 'thugnology', 'oneplus', 'crap', 'lens', 'xs', 'xi', 'alreadywtf', 'twittercomolajvdestatus', 'efkj8m0aemiim4jh0x3cgyiq3d3dutm_sourcecompetitionutm_mediumreferralutm_campaigncompetition20sharing', 'depth', 'fix', 'camera', 'shit', 'life', 'clappedlooks', 'snapchat', 'onboard', 'http', 'turned', 'existedmy', 'xstand', 'compliments', 'system', 'find', 'peoples', 'euro', 'first', 'thats', 'deliver', 'ios', 'that', 'kidney', 'polished', 'maxes', 'make', 'end', 'can', 'chargetecno', 'year', 'replacement', 'verizons', 'watch', 'computer', 'right', 'their', 'with', 'originally', 'takes', ' ...
